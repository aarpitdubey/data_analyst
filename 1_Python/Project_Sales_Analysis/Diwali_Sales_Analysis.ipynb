# %% [markdown]
# ### Import the necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read the File - CSV

# %%
df = pd.read_csv('dataset/Diwali Sales Data.csv', encoding='unicode_escape')

# %%
df.shape
# Out:
# (11251, 14)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 0  1002903  Sanskriti  P00125942      F   28               0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35               1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35               1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16               0       Karnataka
# 4  1000588       Joni  P00057942      M   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount  Status  \
# 0   Western       Healthcare             Auto       1  23952.0     NaN
# 1  Southern             Govt             Auto       3  23934.0     NaN
# 2   Central       Automobile             Auto       3  23924.0     NaN
# 3  Southern     Construction             Auto       2  23912.0     NaN
# 4   Western  Food Processing             Auto       2  23877.0     NaN
#
#    Unnamed
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M   19               1
# 11247  1004089  Reichenbach  P00171342      M   33               0
# 11248  1001209        Oshin  P00201342      F   40               0
# 11249  1004023       Noonan  P00059442      M   37               0
# 11250  1002744      Brumley  P00281742      F   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  Unnamed
# 11246     NaN      NaN
# 11247     NaN      NaN
# ...

# %% [markdown]
# ### NULL Values (or) Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
#  12  Status            0 non-null      float64
#  13  Unnamed           0 non-null      float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ##### Observations:
#
# 1. The DataFrame contains **11251 entries and 14 columns**. The columns include `User_ID`, `Cust_name`, `Product_ID`, `Gender`, `Age`, `Marital_Status`, `State`, `Zone`, `Occupation`, `Product_Category`, `Orders`, `Amount`, `Status`, and `Unnamed`.
# </br></br>
#
# 2. The `User_ID`, `Cust_name`, `Product_ID`, `Gender`, `Age`, `Marital_Status`, `State`, `Zone`, `Occupation`, and `Product_Category` columns have non-null values for all 11251 entries, indicating no missing data for these fields.
# </br></br>
#
#
# 3. The "`Amount`" column has **11239** non-null values, suggesting that there are **some missing values in this column**.
# </br></br>
#
#
# 4. The **"Status"** and **"Unnamed"** columns have 0 non-null values, indicating **no useful data** in these columns.
# </br></br>
#
#
# 5. The data types in the DataFrame include int64, object, and float64, representing integer, string, and floating-point values, respectively.

# %%
df.drop(['Status', 'Unnamed'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender    Age  Marital_Status  State  \
# 0        False      False       False   False  False           False  False
# 1        False      False       False   False  False           False  False
# 2        False      False       False   False  False           False  False
# 3        False      False       False   False  False           False  False
# 4        False      False       False   False  False           False  False
# ...        ...        ...         ...     ...    ...             ...    ...
# 11246    False      False       False   False  False           False  False
# 11247    False      False       False   False  False           False  False
# 11248    False      False       False   False  False           False  False
# 11249    False      False       False   False  False           False  False
# 11250    False      False       False   False  False           False  False
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# 12 rows were amount is null

rows_with_nulls = df[df.isnull().any(axis=1)]

# %%
print(rows_with_nulls)
# Out:
#      User_ID Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 7    1002092  Shivangi  P00273442      F   61               0     Maharashtra
# 14   1003858      Cano  P00293742      M   46               1  Madhya Pradesh
# 16   1005447       Amy  P00275642      F   48               1  Andhra Pradesh
# 109  1005265    Sakshi  P00296242      F   48               1           Delhi
# 111  1005261   Apoorva  P00057942      F   41               1           Delhi
# 184  1005538    Kartik  P00269542      F   49               1       Karnataka
# 293  1000326  Jonathan  P00120542      M   53               0         Gujarat
# 344  1002507   Lakshmi  P00045842      F   35               1         Gujarat
# 345  1004498   Srishti  P00030842      F   55               0           Delhi
# 452  1004601    Gaurav  P00014442      F   40               1  Madhya Pradesh
# 464  1004528    Anurag  P00338442      F   33               1   Uttar Pradesh
# ...

# %% [markdown]
# #### Imputation of null values using median()

# %%
df['Amount'] = df.groupby('Product_Category')['Amount'].transform(lambda x: x.fillna(x.median()))

# %%
selected_rows = df[(df['User_ID'] == 1000326) & (df['Product_ID'] == 'P00120542')]

print(selected_rows)
# Out:
#      User_ID Cust_name Product_ID Gender  Age  Marital_Status    State  \
# 293  1000326  Jonathan  P00120542      M   53               0  Gujarat
#
#         Zone Occupation  Product_Category  Orders   Amount
# 293  Western  IT Sector  Footwear & Shoes       3  16289.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11251 non-null  float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns= {'Marital_Status':'Married'})
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Married           State  \
# 0      1002903    Sanskriti  P00125942      F   28        0     Maharashtra
# 1      1000732       Kartik  P00110942      F   35        1  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F   35        1   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M   16        0       Karnataka
# 4      1000588         Joni  P00057942      M   28        1         Gujarat
# ...        ...          ...        ...    ...  ...      ...             ...
# 11246  1000695      Manning  P00296942      M   19        1     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M   33        0         Haryana
# 11248  1001209        Oshin  P00201342      F   40        0  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M   37        0       Karnataka
# 11250  1002744      Brumley  P00281742      F   19        0     Maharashtra
#
# ...

# %%
def categorize_age(age):
    if age <= 17:
        return '0 - 17'
    elif age <= 25:
        return '18 - 25'
    elif age <= 35:
        return '26 - 35'
    elif age <= 45:
        return '36 - 45'
    elif age <= 50:
        return '46 - 50'
    elif age <= 55:
        return '51 - 55'
    else:
        return '55+'

# %%
df['Age_Group'] = df['Age'].apply(categorize_age)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F   28               0
# 1      1000732       Kartik  P00110942      F   35               1
# 2      1001990        Bindu  P00118542      F   35               1
# 3      1001425       Sudevi  P00237842      M   16               0
# 4      1000588         Joni  P00057942      M   28               1
# ...        ...          ...        ...    ...  ...             ...
# 11246  1000695      Manning  P00296942      M   19               1
# 11247  1004089  Reichenbach  P00171342      M   33               0
# 11248  1001209        Oshin  P00201342      F   40               0
# 11249  1004023       Noonan  P00059442      M   37               0
# 11250  1002744      Brumley  P00281742      F   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11251.000000
# mean      35.421207      2.489290   9461.419607
# std       12.754122      1.115047   5225.272896
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.500000
# 50%       33.000000      2.000000   8110.000000
# 75%       43.000000      3.000000  12691.500000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# #### Observations :
#
# 1. **Age**: The statistical summary for the "Age" column shows that the data includes individuals with a **minimum age of 12, a maximum age of 92**, and a **mean age** of approximately **35.42**. The interquartile range (IQR) indicates that **50%** of the individuals fall between the ages of **27 and 43**, with a **median age** (50th percentile) of **33**.
#
# <br/>
#
# 2. **Orders**: The statistical summary for the "Orders" column reveals that the **count of orders ranges from 1 to 4**, with a **mean** of approximately **2.49**. The **standard deviation** of approximately **1.12** suggests moderate variability around the mean.
#
# <br />
#
# 3. **Amount**: The summary statistics for the "Amount" column highlight a wide range of spending, with the **minimum amount** being **188**, the **maximum amount** being **23952**, and a mean value of approximately **9461.42**. The 25th and 75th percentiles indicate that **50%** of the spending falls within the range of **5443.50 to 12691.50**, while the **median spending** (50th percentile) is approximately **8110**.

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_Group'],
#       dtype='object')

# %% [markdown]
# #### EDA

# %%
ax = sns.countplot(x = 'Gender', data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# #### Observations :
#
# Based on the counts obtained from the countplot, where **7842** is the count for females and **3409** is the count for males, the following observations can be made from the countplot() and its output:
#
# 1. **Gender Distribution**: The countplot() visualizes the distribution of gender within the dataset. It shows a clear difference in the count of females and males, with 7842 females and 3409 males. This observation indicates that **females are making a substantial contribution to the sales during the Diwali season**. The **higher count of female customers** suggests that they play a crucial role in driving **sales and engagement during this festive** period.
# <br>
#
# 2. Additionally, this observation emphasizes the **importance of catering to the preferences and needs of the female customer base**, and **devising targeted marketing strategies to effectively engage and capitalize on their substantial contribution** to the Diwali sales.
# <br>
#
# 3. Understanding and **leveraging the greater presence of female customers can help in tailoring products, promotions, and marketing efforts to maximize sales and customer satisfaction** during the Diwali season.

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender', y = 'Amount', data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# #### Observations :
#
# Now, it is evident that females have a higher purchasing power than males during the Diwali sales period. The analysis of the sales data by gender indicates that the total purchase amount by females substantially exceeds that of males.
#
# - **Purchasing Power**: The barplot reflects that females have a significantly higher purchasing power compared to males, as demonstrated by the noticeably larger total purchase amount attributed to females.
#
# - **Gender-based Sales Contribution**: The analysis shows that females contribute significantly more to the overall sales during the Diwali season, indicating their strong influence on the sales performance.
#
# - **Market Segmentation**: The substantial purchasing power of females emphasizes the importance of segmenting marketing strategies and product offerings to effectively cater to their preferences and drive sales during the festive season.
#
# Understanding the substantial purchasing power of females provides valuable insights for tailored marketing and sales strategies to maximize customer engagement and sales revenue during the Diwali period.

# %% [markdown]
# ## AGE

# %%
ax = sns.countplot(data = df, x = 'Age_Group', hue = 'Gender')

# %%
ax = sns.countplot(data = df, x = 'Age_Group', hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'Age_Group')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Age Group Analysis
#
# ## Observations
#
# - It provides a breakdown of count values by age group, indicating potential targets for marketing strategies.
#
# - **0-17 years**: 296 counts
# - **18-25 years**: 1879 counts
# - **26-35 years**: 4565 counts 🥇
# - **36-45 years**: 2264 counts
# - **46-50 years**: 987 counts
# - **51-55 years**: 832 counts
# - **55+ years**: 428 counts
#
# 📊 The data highlights the **26-35 age group** as the largest segment, suggesting a prime target for marketing efforts. The **18-25** and **36-45 age groups** also show significant counts, indicating additional key demographics for targeted campaigns.
#
# Conversely, the **46-50**, **51-55**, and **55+ age groups** present lower counts, signaling opportunities for tailored strategies to engage these audiences.
#
# 🎯 **Key Takeaway**: Maximizing marketing impact by focusing on the **26-35**, **18-25**, and **36-45 age groups**, while exploring the preferences of lower count age groups to boost sales.

# %%
import matplotlib.pyplot as plt

# Data
labels = ['0-17', '18-25', '26-35', '36-45', '46-50', '51-55', '55+']
sizes = [296, 1879, 4565, 2264, 987, 832, 428]

# Plot
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Age Group Distribution for Targeted Marketing')

# Show plot
plt.show()

# %% [markdown]
# To enhance marketing strategies and increase sales, consider the following:
#
# - **Target the 26-35 age group** with tailored promotions, as they represent the highest count.
# - **Engage the 18-25 and 36-45 age groups** with relevant campaigns to capitalize on their substantial representation.
# - **Research the 46-50, 51-55, and 55+ demographics** to understand their preferences and develop customized marketing approaches.
# - **Monitor purchasing behavior** across all age groups to refine targeting and promotional tactics continuously.
#
# By focusing on these strategies, businesses can effectively allocate their marketing resources and potentially increase their sales figures.

# %%
sales_age = df.groupby(['Age_Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age_Group', y='Amount', data=sales_age)
# Out:
# <Axes: xlabel='Age_Group', ylabel='Amount'>

# %% [markdown]
# ## State

# %%
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(16, 5)})
sns.barplot(data = sales_state, x = 'State', y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(16, 5)})
sns.barplot(data = sales_state, x = 'State', y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(5)

sns.set(rc={'figure.figsize':(16, 5)})
sns.barplot(data = sales_state, x = 'State', y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# ## Marital_Status

# %%
ax = sns.countplot(data = df, x='Marital_Status')

sns.set(rc={'figure.figsize':(7, 5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_maritalStatus = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(5)

sns.set(rc={'figure.figsize':(6, 5)})
sns.barplot(data = sales_maritalStatus, x = 'Marital_Status', y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_Group'],
#       dtype='object')

# %% [markdown]
# ## Occupation

# %%
sns.set(rc={'figure.figsize':(20, 5)})
ax = sns.countplot(data = df, x='Occupation')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_occupation = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20, 5)})
sns.barplot(data = sales_occupation, x = 'Occupation', y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
sales_occupation = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(3)

sns.set(rc={'figure.figsize':(20, 5)})
sns.barplot(data = sales_occupation, x = 'Occupation', y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# ## Product Category

# %%
sns.set(rc={'figure.figsize':(30, 5)})
ax = sns.countplot(data = df, x='Product_Category')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_product_cat = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20, 5)})
sns.barplot(data = sales_product_cat, x = 'Product_Category', y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# ## Product ID

# %%
sales_product_id = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20, 5)})
sns.barplot(data = sales_product_id, x = 'Product_ID', y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
fig1, ax1 = plt.subplots(figsize=(12, 7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ***Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to be to buy products from Food, Clothing and Electronics category.***
