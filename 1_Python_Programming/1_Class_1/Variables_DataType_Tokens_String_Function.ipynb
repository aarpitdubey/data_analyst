# %%
print("Hi, my name is Arpit!")
# Out:
# Hi, my name is Arpit!

# %% [markdown]
# # Python Variables
#
# #### Data/value can be stored in "Temporary Storage Spaces" called Variables.
#
# Question - What is data?
#
# Example -  What is your fav. color?
# Color choices - Blue, Green, Yellow these are some data
#
# - Like when someone ask you what's your favorite color you said it's Blue color and then your memories stores that color then,
# - After a month someone ask again the same question but now, your mood changes and then you said it's Green color and again your memories replace previous color and store this one.
# - Then, again after a month some ask the same question and now, your favorite color becomes Yellow then again in your memory it's replace previous color and stores Yellow color.
#
# Question - In programming, how you can store and remember?
#
# - To store the favorite color in human we have brain but in programming we have a concept of variables.
# - Variable are use to store data and also, we can used the store data through variables
#
# ```python
#
# favorite_color = "Blue"
#
# ```

# %%
favorite_color = "Blue"

print(favorite_color)

after_1_month_favorite_color = "Green"

print(after_1_month_favorite_color)

after_2nd_month_favorite_color = "Yellow"

print(after_2nd_month_favorite_color)
# Out:
# Blue
# Green
# Yellow

# %% [markdown]
# On the other hand, you can said Variable as empty bucket (or) as a empty box which can store the data.
#
# - Variable provides a storage space for data.
# - We can create multiple variable for various type of data (or) we can use same variable for various data but remember whenever we used same variable then every time we replace the previous data with new data.

# %%
# favorite_color is a empty variable and we filled the memory space with "Blue" 
favorite_color = "Blue"

# %%
# This statement shows how our variable remember the data
favorite_color
# Out:
# 'Blue'

# %%
# Now, we have to change the data with "Green"
favorite_color = "Green"

# %% [markdown]
# - Now, the new data replace the stored data and variable name remains the same
#
# - let's check what will be it's output?

# %%
favorite_color
# Out:
# 'Green'

# %% [markdown]
# - As we can see the previous data "Blue" replaced by new data "Green"
#
# - Variable is a temporary store which provide storage space for data.

# %% [markdown]
# # Data Types in Python
#
# #### Each variable is associated with a data type
#
# ![image.png](attachment:f419dd6f-6b31-49e8-a350-28dc0d725a4d.png)

# %%
student_name = "Ravi" # String (or) str data type
roll_number  = 12 # Integer (or) int data type
percentage   = 93.5 # float data type
location     = "Bangalore" # String (or) str data type

print(f"\nHi there, \n\nI am {student_name}, my roll number is {roll_number}\nI have got {percentage}% in 12th standard and\ncurrently persuing my graduation from {location} university.")
# Out:
# Hi there,
#
# I am Ravi, my roll number is 12
# I have got 93.5% in 12th standard and
# currently persuing my graduation from Bangalore university.

# %%
is_sunny   = False
is_raining = True

print(f"\nWhat's the weather of today?\n\nIs it sunny? {is_sunny}\n\n or \n\nis it raining? {is_raining}")
# Out:
# What's the weather of today?
#
# Is it sunny? False
#
#  or
#
# is it raining? True

# %% [markdown]
#  - Remember, we don't have to explicitly mentioned about any of the data type.
#
#  - Like in c, c++ or java we have mentioned about the data type before variable.
#
# ### In C language Variable declaration:
# ```c
# #include <stdio.h>
#
# int main() {
#     int age = 12;  // Variable declaration
#     float height = 73.5;  // Variable declaration
#
#     // Rest of the program
#     return 0;
# }
# ```
# ### In C++ language Variable declaration:
# ```c++
# #include <iostream>
# using namespace std;
#
# int main() {
#     int age = 12;  // Variable declaration
#     double height = 73.5;  // Variable declaration
#
#     // Rest of the program
#     return 0;
# }
#
# ```
# ### In Java language Variable declaration:
# ```java
# public class Main {
#     public static void main(String[] args) {
#         int age = 12;  // Variable declaration
#         double height = 73.5;  // Variable declaration
#
#         // Rest of the program
#     }
# }
#
# ```

# %% [markdown]
# #### Integer (or) int data type

# %%
age = 10

# %%
number_of_toys = 20

# %%
type(age)
# Out:
# int

# %%
type(number_of_toys)
# Out:
# int

# %% [markdown]
# #### float data type

# %%
pi = 3.14

# %%
temperature = 25.5

# %%
type(pi)
# Out:
# float

# %%
type(temperature)
# Out:
# float

# %% [markdown]
# #### String (or) str data type

# %%
name = "Arpit"

# %%
initial_color_character = 'B'

# %%
greetings = "Hello!\nhow are you?"

# %%
type(name)
# Out:
# str

# %%
type(initial_color_character)
# Out:
# str

# %%
type(greetings)
# Out:
# str

# %% [markdown]
# #### Boolean (or) bool data type

# %%
is_raining = True

# %%
is_boring  = False

# %%
type(is_raining)
# Out:
# bool

# %%
type(is_boring)
# Out:
# bool

# %% [markdown]
# #### Complex data type

# %%
complex_number = 3 + 4j

# %%
type(complex_number)
# Out:
# complex

# %% [markdown]
# # Python Tokens
#
# ### Tokens are the smallest meaningful component in a Program
#
# ![image.png](attachment:364e0e8b-e943-42ec-b5e6-3d965c6f03b9.png)

# %%
number1 = 10
number2 = 5

result = number1 + number2

print("The result is:", result)
# Out:
# The result is: 15

# %% [markdown]
# In this code, the tokens include:
#
# Keywords: `print`
#
# Identifiers: `number1`, `number2`, `result`
#
# Operators: `=`, `+`
#
# Literals: `()`, `:`, `"`

# %% [markdown]
# ## Python Keywords
#
# - Keywords are reserved words in Python, having a specific meaning in the language.
#
# ![image.png](attachment:ce3b4a0a-d298-4f5e-aa6a-cb794a4769b0.png)

# %%
import keyword as k

keywords = k.kwlist
print("\n All keywords in Python :\n\n", keywords)
# Out:
#  All keywords in Python :
#
#  ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keywords)
# Out:
# 35

# %%
import platform
print(platform.python_version())
# Out:
# 3.11.3

# %% [markdown]
# ## Python Identifiers
#
# - Identifiers are names used for variables, functions (or) objects.
#
# ![image.png](attachment:aeceb5ad-4466-4148-bcc6-3072f88e3d55.png)
#
# - You cannot use keywords as variables (or) Identifiers.

# %%
name  = "arpit" 
name_ = "ARPIT"

# %%
name == name_
# Out:
# False

# %%
name == name_.lower()
# Out:
# True

# %%
name.upper() == name_
# Out:
# True

# %% [markdown]
# ## Python Literals
#
# - Literals are constants in Python
#
# ![image.png](attachment:bbf490d2-2ed2-492e-b9ee-838c8515c283.png)

# %%
A = 10
print(f"A = {A}")
A = 20
print(f"A = {A}")
# Out:
# A = 10
# A = 20

# %% [markdown]
# Here, A is a variable which can change but the values (or) data to variable 'A' is not changing so, Value/Data is Literals.

# %% [markdown]
# ## Python Operators
#
# - Python operators are special symbols (or) keywords that allows us to perform different operations on variables (or) values.
#
# ![image.png](attachment:e10d8188-1f72-4f8f-a161-bb3b657cf272.png)

# %%
# Arithmetic operators

number_1 = 10
number_2 = 20

# Addition
addition = number_1 + number_2
addition
# Out:
# 30

# %%
# Substraction
substraction = number_2 - number_1
substraction
# Out:
# 10

# %%
# Multiplication

multiplication = number_1 * number_2
multiplication
# Out:
# 200

# %%
# Division

division = number_2 / number_1
division # Floating point (or) float data type result
# Out:
# 2.0

# %%
# Floor Division
floor_division = number_2 // number_1
floor_division # integer (or) int data type result
# Out:
# 2

# %%
# Modulus

modulus = number_1 % number_2
modulus
# Out:
# 10

# %%
# Exponential operator

exponent = number_2 ** number_1
exponent
# Out:
# 10240000000000

# %%
# Relational Operator

number_1 == number_2
# Out:
# False

# %%
number_1 = 100
number_2 = 100
number_1, number_2
# Out:
# (100, 100)

# %%
number_1 == number_2
# Out:
# True

# %%
number_2 = 50
number_1, number_2
# Out:
# (100, 50)

# %%
number_1 != number_1
# Out:
# False

# %%
number_1 > number_2
# Out:
# True

# %%
number_1 < number_2
# Out:
# False

# %%
number_1 >= number_2
# Out:
# True

# %%
number_1 <= number_2
# Out:
# False

# %%
# Logical Operator

w = True
x = False
y = True
z = False

# %%
w and x
# Out:
# False

# %%
w & x
# Out:
# False

# %%
w or x
# Out:
# True

# %%
w | x
# Out:
# True

# %%
w and y
# Out:
# True

# %%
w or y
# Out:
# True

# %%
x and y
# Out:
# False

# %%
x or y
# Out:
# True

# %%
x and z
# Out:
# False

# %%
x or z
# Out:
# False

# %%
not w
# Out:
# False

# %%
not x
# Out:
# True

# %%
not y
# Out:
# False

# %%
not z
# Out:
# True

# %%
# Assignment operators

a = 20

# %%
a += 10
a
# Out:
# 30

# %%
a -= 20
a
# Out:
# 10

# %%
a *= 10
a
# Out:
# 100

# %% [markdown]
# ## Python String (str data type)
#
# - String are sequence of characters, such as letters, numbers, or symbols, enclosed within single quotes (' '), double quotes (" "), or triple quotes (''' ''' or """ """)
#
# ![image.png](attachment:89753381-a9f7-46fd-9484-b8843dcdb172.png)

# %%
# Single line quotes

name = 'Arpit Dubey'
name
# Out:
# 'Arpit Dubey'

# %%
# Double line quotes
greetings = "Hello, how are you?"
greetings
# Out:
# 'Hello, how are you?'

# %%
doctype = """
This a multi-line quotes or we can say it as doctype
It is used to declare the functioning of a fuction.
"""
    
doctype
# Out:
# '\nThis a multi-line quotes or we can say it as doctype\nIt is used to declare the functioning of a fuction.\n'

# %% [markdown]
# ### Slicing or Extracting individual characters
#
# EXAMPLE - 'GROWDATASKILLS'
#
# ![image.png](attachment:9fc4b2c9-8bfa-47ba-8ddf-20d1f83e2ace.png)

# %%
company_name = 'GROWDATASKILLS'

# %%
company_name[0]
# Out:
# 'G'

# %%
company_name[1]
# Out:
# 'R'

# %%
company_name[2]
# Out:
# 'O'

# %%
company_name[3]
# Out:
# 'W'

# %%
company_name[8:]
# Out:
# 'SKILLS'

# %%
company_name[-7]
# Out:
# 'A'

# %%
company_name[-8]
# Out:
# 'T'

# %%
company_name[-10:-6]
# Out:
# 'DATA'

# %%
name = "My name is Arpit Dubey"

# %%
name[0]
# Out:
# 'M'

# %%
name[8]
# Out:
# 'i'

# %%
name[11]
# Out:
# 'A'

# %%
name[11:]
# Out:
# 'Arpit Dubey'

# %% [markdown]
# ### String Functions

# %% [markdown]
# #### Finding length of the string
# - use **len()** function

# %%
company_name = 'GrowDataSkills'
len(company_name)
# Out:
# 14

# %% [markdown]
# #### Converting string to upper case
# - Use **upper()** function

# %%
company_name.upper()
# Out:
# 'GROWDATASKILLS'

# %% [markdown]
# #### Converting string to lower case
# - Use **lower()** function

# %%
company_name.lower()
# Out:
# 'growdataskills'

# %% [markdown]
# #### Replacing a substring
# - Use **replace()** function

# %%
message = "We are GrowDataSkills"

message.replace("D", "z")
# Out:
# 'We are GrowzataSkills'

# %% [markdown]
# #### Finding the index of substring
# - Use **find()** function

# %%
message.find('are')
# Out:
# 3

# %% [markdown]
# #### Number of Occurrences of substring
# - Use **count()** function

# %%
message.count("a")
# Out:
# 3

# %% [markdown]
# #### Splitting a string
# - Use **split()** function

# %%
message.split(" ")
# Out:
# ['We', 'are', 'GrowDataSkills']
